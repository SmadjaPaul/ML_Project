# %% [markdown]
# <a href="https://colab.research.google.com/github/SmadjaPaul/ML_Project/blob/master/Deepfake.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Demo for paper "First Order Motion Model for Image Animation"

# %% [markdown]
# **Clone repository**

# %%
# !git clone https://github.com/AliaksandrSiarohin/first-order-model
# Out:
# Cloning into 'first-order-model'...
# remote: Enumerating objects: 32, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 193 (delta 15), reused 12 (delta 5), pack-reused 161
# Receiving objects: 100% (193/193), 71.45 MiB | 10.14 MiB/s, done.
# Resolving deltas: 100% (92/92), done.

# %%
cd first-order-model
# Out:
# /content/first-order-model

# %% [markdown]
# **Mount your Google drive folder on Colab**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# **Add folder https://drive.google.com/drive/folders/1kZ1gCnpfU0BnpdU47pLM_TQ6RypDDqgw?usp=sharing  to your google drive.**

# %% [markdown]
# **Load driving video and source image**

# %%
import imageio
#danerys
#source_image = imageio.imread('/content/gdrive/My Drive/deepfake/first-order-motion-model/got-05.png')
#sansa
#source_image = imageio.imread('/content/gdrive/My Drive/deepfake/first-order-motion-model/got-06.png')

#john
source_image = imageio.imread('/content/gdrive/My Drive/deepfake/first-order-motion-model/got-03.png')

#shreak
#source_image = imageio.imread('/content/gdrive/My Drive/deepfake/first-order-motion-model/cartoons-01.png')

#statue
#source_image = imageio.imread('/content/gdrive/My Drive/deepfake/first-order-motion-model/statue-01.png')

#mechant
#source_image = imageio.imread('/content/gdrive/My Drive/deepfake/first-order-motion-model/got-01.png')

#shreak 
#source_image = imageio.imread('/content/gdrive/My Drive/first-order-motion-model/cartoons-01.png')

#Dark vador
#source_image = imageio.imread('/content/gdrive/My Drive/deepfake/first-order-motion-model/Dark.jpg')
#source_image = imageio.imread('/content/gdrive/My Drive/deepfake/first-order-motion-model/dark2.jpg')
#source_image = imageio.imread('/content/gdrive/My Drive/deepfake/first-order-motion-model/anakin.jpg')

# %%
driving_video = imageio.mimread('/content/gdrive/My Drive/deepfake/first-order-motion-model/04.mp4')

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from skimage.transform import resize
from IPython.display import HTML
import warnings
warnings.filterwarnings("ignore")




#Resize image and video to 256x256

source_image = resize(source_image, (256, 256))[..., :3]
driving_video = [resize(frame, (256, 256))[..., :3] for frame in driving_video]

def display(source, driving, generated=None):
    fig = plt.figure(figsize=(8 + 4 * (generated is not None), 6))

    ims = []
    for i in range(len(driving)):
        cols = [source]
        cols.append(driving[i])
        if generated is not None:
            cols.append(generated[i])
        im = plt.imshow(np.concatenate(cols, axis=1), animated=True)
        plt.axis('off')
        ims.append([im])

    ani = animation.ArtistAnimation(fig, ims, interval=50, repeat_delay=1000)
    plt.close()
    return ani
    

HTML(display(source_image, driving_video).to_html5_video())
# Out:
# <video width="576" height="432" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# **Create a model and load checkpoints**

# %%
from demo import load_checkpoints
generator, kp_detector = load_checkpoints(config_path='config/vox-256.yaml', 
                            checkpoint_path='/content/gdrive/My Drive/deepfake/first-order-motion-model/vox-cpk.pth.tar')

# %% [markdown]
# **Perfrorm image animation**

# %%
from demo import make_animation
from skimage import img_as_ubyte

predictions = make_animation(source_image, driving_video, generator, kp_detector, relative=True)

#save resulting video
imageio.mimsave('../generated.mp4', [img_as_ubyte(frame) for frame in predictions])
#video can be downloaded from /content folder

HTML(display(source_image, driving_video, predictions).to_html5_video())
# Out:
# 100%|██████████| 211/211 [00:25<00:00,  8.21it/s]
# <video width="864" height="432" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# **In the cell above we use relative keypoint displacement to animate the objects. We can use absolute coordinates instead,  but in this way all the object proporions will be inherited from the driving video. For example Putin haircut will be extended to match Trump haircut.**

# %%
predictions = make_animation(source_image, driving_video, generator, kp_detector, relative=False, adapt_movement_scale=True)
HTML(display(source_image, driving_video, predictions).to_html5_video())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-b309380617de> in <module>()
# ----> 1 predictions = make_animation(source_image, driving_video, generator, kp_detector, relative=False, adapt_movement_scale=True)
#       2 HTML(display(source_image, driving_video, predictions).to_html5_video())
#
# NameError: name 'make_animation' is not defined

# %% [markdown]
# ## Running on your data
#
# **First we need to crop a face from both source image and video, while simple graphic editor like paint can be used for cropping from image. Cropping from video is more complicated. You can use ffpmeg for this.**

# %%
# !ffmpeg -i /content/gdrive/My\ Drive/deepfake/lulu/1.mkv -ss 00:08:57.50 -t 00:00:08 -filter:v "crop=600:600:760:50" -async 1 hinton.mp4
# Out:
# ffmpeg version 3.4.6-0ubuntu0.18.04.1 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
# ...

# %% [markdown]
# **Another posibility is to use some screen recording tool, or if you need to crop many images at ones use face detector(https://github.com/1adrianb/face-alignment) , see https://github.com/AliaksandrSiarohin/video-preprocessing for preprcessing of VoxCeleb.**

# %%
import imageio
#danerys
#source_image = imageio.imread('/content/gdrive/My Drive/deepfake/first-order-motion-model/got-05.png')
#sansa
#source_image = imageio.imread('/content/gdrive/My Drive/deepfake/first-order-motion-model/got-06.png')

#john
#source_image = imageio.imread('/content/gdrive/My Drive/deepfake/first-order-motion-model/got-03.png')

#shreak
#source_image = imageio.imread('/content/gdrive/My Drive/deepfake/first-order-motion-model/cartoons-01.png')

#statue
#source_image = imageio.imread('/content/gdrive/My Drive/deepfake/first-order-motion-model/statue-01.png')

#mechant
#source_image = imageio.imread('/content/gdrive/My Drive/deepfake/first-order-motion-model/got-01.png')

#shreak 
#source_image = imageio.imread('/content/gdrive/My Drive/first-order-motion-model/cartoons-01.png')

#Dark vador
#source_image = imageio.imread('/content/gdrive/My Drive/deepfake/first-order-motion-model/Dark.jpg')
#source_image = imageio.imread('/content/gdrive/My Drive/deepfake/first-order-motion-model/dark2.jpg')
source_image = imageio.imread('/content/gdrive/My Drive/deepfake/first-order-motion-model/anakin.jpg')

# %%
driving_video = imageio.mimread('/content/gdrive/My Drive/deepfake/lulu/8.mp4', memtest=False)


#Resize image and video to 256x256

source_image = resize(source_image, (256, 256))[..., :3]
driving_video = [resize(frame, (256, 256))[..., :3] for frame in driving_video]

predictions = make_animation(source_image, driving_video, generator, kp_detector, relative=True,
                             adapt_movement_scale=True)

HTML(display(source_image, driving_video, predictions).to_html5_video())
# Out:
# 100%|██████████| 175/175 [00:21<00:00,  8.24it/s]
# <video width="864" height="432" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
imageio.mimwrite('/content/gdrive/My Drive/deepfake/lulu/8-final.mp4', predictions)
# Out:
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# ...
